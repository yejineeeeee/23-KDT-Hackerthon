# %%
! ls
# Out:
# Data  runs  tree.yaml  yolov8n.pt  yolov8_tree.ipynb

# %%
import zipfile

# %%
##  liblzma-dev 설치 > python3.9 설치 > 가상환경 KT (source /home/msmlwork2/Python-3.9.0/kt2/bin/activate) > ultralytics, torch, torchvision 설치
## > IDE의 python 인터프리터가 가상환경의 python 사용하도록 설정

# %%
import sys
print(sys.executable)
# sys.path.append('/path/to/ultralytics'
print(sys.path)
# Out:
# /home/msmlwork2/Python-3.9.0/kt2/bin/python3.9
# ['/home/msmlwork2/Documents/KT', '/home/msmlwork2/Documents/KT', '/path/to/ultralytics', '/usr/local/lib/python39.zip', '/usr/local/lib/python3.9', '/usr/local/lib/python3.9/lib-dynload', '', '/home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages']

# %%
### 터미널에서 GPU 사용 상황 확인
# !nvidia-smi
# Out:
# Failed to initialize NVML: Driver/library version mismatch

# %%
# import ultralytics
from ultralytics import YOLO
import torch
import os

model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Train the model
current_directory = os.getcwd()
file_path = os.path.join(current_directory, "tree.yaml")
model.train(data=file_path, epochs=100, patience=30, batch=64)

metrics = model.val()  # evaluate model performance on the validation set
# Out:
# New https://pypi.org/project/ultralytics/8.0.196 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.0 torch-2.0.1+cu117 CUDA:0 (Quadro P5000, 16265MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/msmlwork2/Documents/KT/tree.yaml, epochs=100, patience=30, batch=64, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=14
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    754042  ultralytics.nn.modules.head.Detect           [14, [64, 128, 256]]
# Model summary: 225 layers, 3013578 parameters, 3013562 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/msmlwork2/Documents/KT/Data/Tree_train/labels.cache... 112
# val: Scanning /home/msmlwork2/Documents/KT/Data/Tree_valid/labels.cache... 1400
# Plotting labels to runs/detect/train2/labels.jpg...
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46181 (\N{HANGUL SYLLABLE DUNG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49100 (\N{HANGUL SYLLABLE BBU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47943 (\N{HANGUL SYLLABLE MUS}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51086 (\N{HANGUL SYLLABLE IP}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45348 (\N{HANGUL SYLLABLE NE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51536 (\N{HANGUL SYLLABLE JWI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47492 (\N{HANGUL SYLLABLE REUM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45804 (\N{HANGUL SYLLABLE DAL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46181 (\N{HANGUL SYLLABLE DUNG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49100 (\N{HANGUL SYLLABLE BBU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47943 (\N{HANGUL SYLLABLE MUS}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51086 (\N{HANGUL SYLLABLE IP}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45348 (\N{HANGUL SYLLABLE NE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51536 (\N{HANGUL SYLLABLE JWI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47492 (\N{HANGUL SYLLABLE REUM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45804 (\N{HANGUL SYLLABLE DAL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      15.3G      1.032      2.556       1.17       2039        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.752      0.725      0.792      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      14.6G     0.8883     0.9764      1.079       2133        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.885      0.851      0.915      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      12.4G     0.8741     0.8384      1.063       2066        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.786      0.662      0.767      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      11.6G     0.8538     0.7776      1.057       2100        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.901      0.875      0.932      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      12.4G     0.8228     0.7181      1.045       2064        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.894      0.861      0.926      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      15.9G     0.8018     0.6798      1.038       2039        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.923      0.902      0.953      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      11.2G     0.7868     0.6476      1.033       2301        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.926      0.904      0.954      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100        14G      0.773     0.6202      1.026       1969        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.919      0.885      0.946       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      12.7G     0.7661     0.5999      1.024       2130        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.936      0.916      0.963      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      14.3G      0.757     0.5822      1.021       2172        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.932      0.914      0.961      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      13.6G     0.7537     0.5673      1.018       2248        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.927      0.898      0.952      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      11.9G     0.7442     0.5576      1.017       2339        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.938      0.924      0.964      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      12.6G     0.7372     0.5456      1.013       2144        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.945      0.924      0.968      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100        13G     0.7323     0.5377      1.012       2072        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.943      0.921      0.966       0.81
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      13.8G     0.7308     0.5313      1.009       2472        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.942      0.924      0.967       0.81
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      12.7G     0.7247     0.5244      1.007       2158        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290       0.95      0.926       0.97      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      10.7G     0.7192      0.516      1.005       2457        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.951      0.933      0.971      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      15.9G     0.7204     0.5103      1.005       2134        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.955      0.937      0.973      0.837
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      16.1G     0.7172     0.5069      1.005       2121        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.947      0.931      0.971      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      12.8G     0.7142     0.5049      1.003       1976        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.942      0.923      0.966      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      11.5G     0.7097     0.4976      1.001       2182        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.952      0.939      0.975      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      14.3G     0.7107     0.4941      1.001       2149        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0
0.982      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      14.1G     0.6432     0.4079     0.9663       2108        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.964      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      12.2G     0.6409     0.4065     0.9646       2238        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.964      0.958      0.982      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      13.5G     0.6422     0.4076     0.9658       2167        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.964      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100        13G     0.6414     0.4065     0.9657       2371        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.964      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      15.7G     0.6368     0.4024     0.9622       2237        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.957      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100        15G     0.6378     0.4024      0.963       2282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.964      0.957      0.982      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      11.3G     0.6308     0.3996     0.9618       2258        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.958      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      16.2G     0.6354     0.4014     0.9627       2297        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.964      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      15.3G     0.6334     0.3998     0.9624       1920        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.966      0.957      0.982      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      14.9G     0.6327      0.399     0.9605       2334        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.964      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      15.8G     0.6305     0.3971     0.9587       1887        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.966      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      13.9G     0.6313     0.3958     0.9603       2157        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.966      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      13.7G     0.6328     0.3953     0.9599       2297        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.958      0.982      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      16.5G       0.63     0.3933     0.9601       1889        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.958      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      12.5G     0.6292      0.394     0.9589       2129        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.959      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      15.5G     0.6269     0.3919     0.9568       1963        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.959      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      16.3G     0.6243     0.3902     0.9577       2394        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965       0.96      0.982       0.87
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      13.3G      0.577     0.3457       0.93       1483        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965       0.96      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      12.9G     0.5707     0.3393     0.9282       1232        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.959      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      11.3G     0.5678     0.3371      0.925       1290        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.966      0.959      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      12.6G     0.5665     0.3352     0.9259       1557        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.965      0.959      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      12.3G     0.5627     0.3315     0.9233       1381        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.966      0.959      0.982       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      12.2G       0.56     0.3299     0.9217       1402        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      32290      0.966      0.959      0.982       0.87
#
# ...
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47943 (\N{HANGUL SYLLABLE MUS}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 51086 (\N{HANGUL SYLLABLE IP}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 45348 (\N{HANGUL SYLLABLE NE}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 51536 (\N{HANGUL SYLLABLE JWI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47492 (\N{HANGUL SYLLABLE REUM}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 45804 (\N{HANGUL SYLLABLE DAL}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
#                    all       1400      32290      0.966      0.959      0.982      0.871
#                   나무전체       1400       1400      0.993      0.999      0.995      0.968
#                     기둥       1400       1400      0.982      0.981      0.992      0.813
#                     수관       1400       1490      0.976      0.977      0.991      0.967
#                     가지       1400       2143      0.931      0.892      0.954      0.773
#                     뿌리       1400       1416      0.978      0.979      0.992      0.862
#                    나뭇잎       1400       4050      0.919      0.871      0.938      0.732
#                      꽃       1400       2821      0.972      0.966      0.987      0.883
#                     열매       1400       4824      0.936      0.897      0.955      0.772
#                     그네       1400       1409      0.977      0.989      0.992      0.933
#                      새       1400       1506       0.95       0.96      0.985      0.905
#                    다람쥐       1400       1418      0.967      0.963      0.988      0.902
#                     구름       1400       2605       0.98      0.983      0.993      0.934
#                      달       1400       1406      0.981      0.991      0.994      0.917
#                      별       1400       4402      0.983      0.981      0.993      0.834
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46181 (\N{HANGUL SYLLABLE DUNG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49100 (\N{HANGUL SYLLABLE BBU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47943 (\N{HANGUL SYLLABLE MUS}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51086 (\N{HANGUL SYLLABLE IP}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45348 (\N{HANGUL SYLLABLE NE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51536 (\N{HANGUL SYLLABLE JWI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47492 (\N{HANGUL SYLLABLE REUM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45804 (\N{HANGUL SYLLABLE DAL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46181 (\N{HANGUL SYLLABLE DUNG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49100 (\N{HANGUL SYLLABLE BBU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47943 (\N{HANGUL SYLLABLE MUS}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51086 (\N{HANGUL SYLLABLE IP}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45348 (\N{HANGUL SYLLABLE NE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49352 (\N{HANGUL SYLLABLE SAE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51536 (\N{HANGUL SYLLABLE JWI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47492 (\N{HANGUL SYLLABLE REUM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45804 (\N{HANGUL SYLLABLE DAL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# Speed: 0.6ms preprocess, 5.8ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/val

# %%
path = model.export(format="onnx")  # export the model to ONNX format
model_path = os.path.join(current_directory, "yolov8_tree.pt")
torch.save(model.state_dict(), model_path)
print(f"Model has been saved to {model_path}")
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.0 torch-2.0.1+cu117 CPU (Intel Core(TM) i9-9980XE 3.00GHz)
#
# PyTorch: starting from 'runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 18, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 1.0s, saved as 'runs/detect/train2/weights/best.onnx' (11.7 MB)
#
# Export complete (3.1s)
# Results saved to /home/msmlwork2/Documents/KT/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=runs/detect/train2/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train2/weights/best.onnx imgsz=640 data=/home/msmlwork2/Documents/KT/tree.yaml
# Visualize:       https://netron.app
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Model has been saved to /home/msmlwork2/Documents/KT/yolov8_tree.pt

# %%
# import shutil

# shutil.make_archive("/content/runs", 'zip', "/content/runs")
