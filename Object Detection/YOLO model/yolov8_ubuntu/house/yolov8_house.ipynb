# %%
! ls
# Out:
# Data  house.yaml  runs	yolov8.ipynb  yolov8n.pt  yolov8.pt

# %%
import zipfile

# %%
##  liblzma-dev 설치 > python3.9 설치 > 가상환경 KT (source /home/msmlwork2/Python-3.9.0/kt2/bin/activate) > ultralytics, torch, torchvision 설치
## > IDE의 python 인터프리터가 가상환경의 python 사용하도록 설정

# %%
import sys
print(sys.executable)
# sys.path.append('/path/to/ultralytics'
print(sys.path)
# Out:
# /home/msmlwork2/Python-3.9.0/kt2/bin/python3.9
# ['/home/msmlwork2/Documents/KT', '/home/msmlwork2/Documents/KT', '/path/to/ultralytics', '/usr/local/lib/python39.zip', '/usr/local/lib/python3.9', '/usr/local/lib/python3.9/lib-dynload', '', '/home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages']

# %%
# import ultralytics
from ultralytics import YOLO
import torch
import os

model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Train the model
current_directory = os.getcwd()
file_path = os.path.join(current_directory, "house.yaml")
model.train(data=file_path, epochs=100, patience=30, batch=64)

metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 6.96MB/s]
# New https://pypi.org/project/ultralytics/8.0.191 available 😃 Update with 'pip install -U ultralytics'
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.0 torch-2.0.1+cu117 CUDA:0 (Quadro P5000, 16270MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/msmlwork2/Documents/KT/house.yaml, epochs=100, patience=30, batch=64, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train5
# Overriding model.yaml nc=80 with nc=15
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    754237  ultralytics.nn.modules.head.Detect           [15, [64, 128, 256]]
# Model summary: 225 layers, 3013773 parameters, 3013757 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/msmlwork2/Documents/KT/Data/House_train/labels... 11200 im
# train: New cache created: /home/msmlwork2/Documents/KT/Data/House_train/labels.cache
# val: Scanning /home/msmlwork2/Documents/KT/Data/House_valid/labels.cache... 1400
# Plotting labels to runs/detect/train5/labels.jpg...
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48533 (\N{HANGUL SYLLABLE BUNG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48317 (\N{HANGUL SYLLABLE BYEOG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46749 (\N{HANGUL SYLLABLE DDUG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47803 (\N{HANGUL SYLLABLE MOS}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51092 (\N{HANGUL SYLLABLE JAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48533 (\N{HANGUL SYLLABLE BUNG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48317 (\N{HANGUL SYLLABLE BYEOG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46749 (\N{HANGUL SYLLABLE DDUG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47803 (\N{HANGUL SYLLABLE MOS}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51092 (\N{HANGUL SYLLABLE JAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train5
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      12.4G     0.9733       2.73      1.163       2048        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.806      0.729       0.81      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      12.1G      0.819      1.011      1.069       2055        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.881      0.843       0.91      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      10.2G     0.8136     0.8754      1.057       1880        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.308      0.125      0.106     0.0677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      11.1G     0.7992     0.8188      1.053       1951        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.914      0.883      0.937      0.792
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      10.1G     0.7655     0.7611      1.041       2067        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.911      0.875      0.937      0.794
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      12.4G     0.7474     0.7186      1.035       1988        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.574      0.108      0.174      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      11.5G     0.7327      0.688      1.027       2262        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.928      0.909      0.957      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      9.76G     0.7159     0.6606       1.02       1953        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.938      0.911       0.96      0.824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      9.48G     0.7067     0.6383      1.016       2131        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.931      0.912       0.96      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      12.7G     0.6983     0.6249      1.015       1910        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.935      0.913       0.96      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      10.5G     0.6892     0.6085      1.009       2037        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.943      0.922      0.965       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      11.3G      0.687     0.5959      1.009       2003        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.944      0.926      0.968      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      9.95G     0.6797     0.5842      1.004       1967        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.941      0.927      0.966      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      12.6G     0.6745     0.5762      1.004       2110        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.929      0.897      0.948      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      9.81G     0.6725     0.5669      1.001       2309        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.949      0.936      0.973      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      11.3G     0.6639     0.5587     0.9962       2097        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.943      0.936       0.97      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100       9.8G      0.661     0.5539      0.995       2154        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285       0.95      0.943      0.973      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      12.5G     0.6559     0.5424     0.9914       2053        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.954      0.941      0.975      0.878
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      11.8G     0.6531     0.5398     0.9902       2027        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.952      0.935      0.972      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      11.4G     0.6502     0.5355     0.9891       1857        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.944      0.923      0.964      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      10.8G     0.6498     0.5329     0.9901       1885        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.938      0.916       0.96      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      11.2G     0.6465     0.5255     0.9861       2163        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.945      0.934      0.971       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      10.8G     0.6444     0.5225     0.9862       2036        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.948      0.939      0.972      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      10.6G     0.6397     0.5149     0.9828       1909        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.958      0.942      0.976       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.969      0.961      0.984      0.909
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      10.2G     0.5718     0.4201     0.9521       2256        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.962      0.984       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      12.3G     0.5712     0.4187     0.9498       2121        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.966      0.963      0.984       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      10.6G     0.5704     0.4187       0.95       2119        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.962      0.984       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      10.2G      0.566     0.4148     0.9481       2333        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.967      0.962      0.984       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      11.8G     0.5684     0.4154     0.9511       2211        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.967      0.962      0.984       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      11.1G      0.569      0.415     0.9499       1837        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.962      0.984       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100        11G     0.5636     0.4115     0.9467       2207        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.962      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      11.4G     0.5653     0.4114     0.9469       1851        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.962      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      12.7G     0.5633     0.4095      0.947       2062        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.969      0.961      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      12.7G     0.5623     0.4093     0.9464       2068        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.961      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      10.8G     0.5612     0.4082     0.9473       1922        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.961      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      9.67G     0.5615     0.4074     0.9463       2064        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.969       0.96      0.984       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      10.4G     0.5589     0.4041     0.9444       1859        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.968      0.961      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      10.6G     0.5574     0.4035     0.9458       2176        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.969      0.961      0.984      0.911
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      9.73G     0.4981     0.3413     0.9033       1195        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285       0.97       0.96      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      11.8G     0.4919     0.3325     0.9018       1158        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285       0.97      0.961      0.984      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      10.2G     0.4887     0.3289     0.9003       1250        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.969      0.962      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      9.64G     0.4891     0.3284     0.9015       1207        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.971       0.96      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      11.3G     0.4851     0.3249     0.8975       1226        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.969      0.962      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      10.6G     0.4847     0.3239     0.8991       1248        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285      0.969      0.962      0.984      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      10.5G     0.4825     0.3215     0.8975       1239        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      29285       0.97      0.961      0.984      0.912
#
# ...
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 46749 (\N{HANGUL SYLLABLE DDUG}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47803 (\N{HANGUL SYLLABLE MOS}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 51092 (\N{HANGUL SYLLABLE JAN}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
#                    all       1400      29285      0.972       0.96      0.984      0.913
#                    집전체       1400       1401      0.996      0.998      0.995      0.977
#                     지붕       1400       1417      0.994      0.988      0.995      0.965
#                     집벽       1400       1420      0.994      0.992      0.995      0.969
#                      문       1400       1425       0.99      0.985      0.993      0.928
#                     창문       1400       2434      0.985       0.96       0.99      0.894
#                     굴뚝       1400       1405      0.981      0.977      0.991      0.924
#                     연기       1400       1406      0.977      0.966       0.99        0.9
#                    울타리       1400       2044      0.944      0.923      0.971      0.883
#                      길       1400       1443       0.94      0.938      0.975      0.911
#                     연못       1400       1407      0.978       0.99      0.994      0.967
#                      산       1400       1651      0.915      0.905      0.955      0.872
#                     나무       1400       1695      0.982      0.976      0.993      0.949
#                      꽃       1400       2922       0.98       0.95      0.987      0.872
#                     잔디       1400       5811      0.938      0.866      0.943      0.735
#                     태양       1400       1404      0.981      0.986      0.993      0.952
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48533 (\N{HANGUL SYLLABLE BUNG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48317 (\N{HANGUL SYLLABLE BYEOG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46749 (\N{HANGUL SYLLABLE DDUG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47803 (\N{HANGUL SYLLABLE MOS}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51092 (\N{HANGUL SYLLABLE JAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51665 (\N{HANGUL SYLLABLE JIB}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48533 (\N{HANGUL SYLLABLE BUNG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48317 (\N{HANGUL SYLLABLE BYEOG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46749 (\N{HANGUL SYLLABLE DDUG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47803 (\N{HANGUL SYLLABLE MOS}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44867 (\N{HANGUL SYLLABLE GGOC}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51092 (\N{HANGUL SYLLABLE JAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# Speed: 0.7ms preprocess, 4.6ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/val2

# %%
path = model.export(format="onnx")  # export the model to ONNX format
model_path = os.path.join(current_directory, "yolov8_house.pt")
torch.save(model.state_dict(), model_path)
print(f"Model has been saved to {model_path}")
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.0 torch-2.0.1+cu117 CPU (Intel Core(TM) i9-9980XE 3.00GHz)
#
# PyTorch: starting from 'runs/detect/train5/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 19, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 0.5s, saved as 'runs/detect/train5/weights/best.onnx' (11.7 MB)
#
# Export complete (2.7s)
# Results saved to /home/msmlwork2/Documents/KT/runs/detect/train5/weights
# Predict:         yolo predict task=detect model=runs/detect/train5/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train5/weights/best.onnx imgsz=640 data=/home/msmlwork2/Documents/KT/house.yaml
# Visualize:       https://netron.app
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Model has been saved to /home/msmlwork2/Documents/KT/yolov8_house.pt

# %%
# import shutil

# shutil.make_archive("/content/runs", 'zip', "/content/runs")
