# %%
! ls
# Out:
# Data  house.yaml  runs	yolov8.ipynb  yolov8n.pt  yolov8.pt

# %%
import zipfile

# %%
##  liblzma-dev 설치 > python3.9 설치 > 가상환경 KT (source /home/msmlwork2/Python-3.9.0/kt2/bin/activate) > ultralytics, torch, torchvision 설치
## > IDE의 python 인터프리터가 가상환경의 python 사용하도록 설정

# %%
import sys
print(sys.executable)
# sys.path.append('/path/to/ultralytics'
print(sys.path)
# Out:
# /home/msmlwork2/Python-3.9.0/kt2/bin/python3.9
# ['/home/msmlwork2/Documents/KT', '/home/msmlwork2/Documents/KT', '/path/to/ultralytics', '/usr/local/lib/python39.zip', '/usr/local/lib/python3.9', '/usr/local/lib/python3.9/lib-dynload', '', '/home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages']

# %%
# import ultralytics
from ultralytics import YOLO
import torch
import os

model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Train the model
current_directory = os.getcwd()
file_path = os.path.join(current_directory, "man.yaml")
model.train(data=file_path, epochs=100, patience=30, batch=64)

metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 10.2MB/s]
# New https://pypi.org/project/ultralytics/8.0.197 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.0 torch-2.0.1+cu117 CUDA:0 (Quadro P5000, 16265MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/msmlwork2/Documents/KT/man.yaml, epochs=100, patience=30, batch=64, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=18
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    754822  ultralytics.nn.modules.head.Detect           [18, [64, 128, 256]]
# Model summary: 225 layers, 3014358 parameters, 3014342 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/msmlwork2/Documents/KT/Data/Man_train/labels... 11200 imag
# train: WARNING ⚠️ /home/msmlwork2/Documents/KT/Data/Man_train/images/남자사람_12_남_07461.jpg: 1 duplicate labels removed
# train: New cache created: /home/msmlwork2/Documents/KT/Data/Man_train/labels.cache
# val: Scanning /home/msmlwork2/Documents/KT/Data/Man_valid/labels... 1400 images,
# val: New cache created: /home/msmlwork2/Documents/KT/Data/Man_valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47672 (\N{HANGUL SYLLABLE MEO}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50620 (\N{HANGUL SYLLABLE EOL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45576 (\N{HANGUL SYLLABLE NUN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51077 (\N{HANGUL SYLLABLE IB}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46973 (\N{HANGUL SYLLABLE RAG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46160 (\N{HANGUL SYLLABLE DU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47672 (\N{HANGUL SYLLABLE MEO}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50620 (\N{HANGUL SYLLABLE EOL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45576 (\N{HANGUL SYLLABLE NUN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51077 (\N{HANGUL SYLLABLE IB}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46973 (\N{HANGUL SYLLABLE RAG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/plotting.py:312: UserWarning: Glyph 46160 (\N{HANGUL SYLLABLE DU}) missing from current font.
#   plt.savefig(fname, dpi=200)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      13.7G      1.058      2.443       1.06       2290        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660       0.85      0.837      0.879      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100        13G     0.8784     0.8206     0.9585       2419        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660        0.9      0.897      0.933      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      12.9G     0.8696     0.7255     0.9566       2195        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.885      0.864      0.897      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      12.9G     0.8368     0.6634     0.9491       2399        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.939      0.925      0.953      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      11.9G     0.7978     0.6106     0.9387       2582        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.935      0.926      0.956      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      13.8G     0.7756     0.5775     0.9335       2304        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.947      0.938      0.964      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      12.8G     0.7571     0.5513     0.9296       2612        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.954      0.943      0.967      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      12.8G     0.7462     0.5266     0.9242       2249        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.934      0.916      0.939      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      12.7G     0.7349     0.5091     0.9224       2416        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.938      0.924      0.956       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      13.8G     0.7279     0.4955     0.9198       2422        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.956      0.944      0.971      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      11.1G     0.7209     0.4832     0.9174       2569        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.954      0.944      0.967      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      13.6G     0.7153     0.4746     0.9169       2495        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660       0.96       0.95      0.972      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      10.1G     0.7071     0.4651     0.9145       2553        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.962      0.949      0.971      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100        12G     0.7025     0.4581     0.9124       2288        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.952      0.941      0.969      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      13.7G     0.6973     0.4509     0.9111       2911        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.959      0.953      0.973      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      10.1G     0.6969     0.4463     0.9113       2652        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.964      0.953      0.976      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      11.8G     0.6894     0.4414     0.9082       2756        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.955      0.943      0.969      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      11.1G     0.6848      0.435     0.9075       2597        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.959      0.947      0.973      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      12.8G     0.6838     0.4327     0.9076       2496        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.967      0.956      0.977      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      12.7G      0.679     0.4281     0.9056       2343        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.966      0.958      0.978      0.813
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      13.8G     0.6783      0.427     0.9067       2295        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.959       0.95       0.97      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      11
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.975      0.969      0.985      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      10.1G     0.6095     0.3545     0.8869       2537        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.984      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      12.9G     0.6069     0.3523     0.8848       2584        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.977      0.969      0.985      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      11.9G     0.6075     0.3509     0.8864       2558        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100        12G     0.6067     0.3516     0.8864       2799        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.977      0.968      0.985      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      12.9G      0.606     0.3499     0.8844       2587        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976       0.97      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      12.8G      0.603     0.3485     0.8851       2623        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.977      0.969      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      13.8G     0.6031     0.3482     0.8862       2678        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.984      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      10.6G     0.6032     0.3481     0.8857       2554        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976       0.97      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      11.1G     0.6003     0.3452      0.885       2178        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976       0.97      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100        12G     0.5993     0.3441     0.8848       2705        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      12.9G     0.5982     0.3446     0.8829       2248        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      12.8G     0.5962     0.3431      0.883       2559        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976       0.97      0.985      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100        11G      0.597     0.3415     0.8829       2557        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.985      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      12.7G     0.5958     0.3414     0.8837       2108        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.985      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100        12G     0.5938       0.34     0.8817       2436        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976      0.969      0.985      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      12.9G     0.5953     0.3401     0.8816       2432        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1400      37660      0.976       0.97      0.985      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100        12G     0.5917     0.3385     0.8816       2699        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
# ...
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:369: UserWarning: Glyph 46160 (\N{HANGUL SYLLABLE DU}) missing from current font.
#   fig.savefig(save_dir, dpi=250)
#                    all       1400      37660      0.978      0.969      0.985      0.847
#                   사람전체       1400       1401          1      0.999      0.995       0.99
#                     머리       1400       1400      0.999      0.999      0.995      0.979
#                     얼굴       1400       1400      0.998      0.999      0.995      0.964
#                      눈       1400       2800      0.966      0.915      0.964      0.728
#                      코       1400       1400      0.961      0.843      0.933      0.639
#                      입       1400       1400      0.979      0.954      0.984      0.791
#                      귀       1400       2790      0.987      0.989      0.994      0.785
#                   머리카락       1400       1400      0.988      0.995      0.994      0.903
#                      목       1400       1400      0.986      0.991      0.994       0.72
#                     상체       1400       1400      0.998      0.998      0.995      0.959
#                      팔       1400       2800      0.995      0.995      0.995      0.918
#                      손       1400       2794      0.989      0.989      0.995      0.831
#                     다리       1400       2798      0.959      0.981      0.992       0.93
#                      발       1400       2800      0.981       0.99      0.993      0.835
#                     단추       1400       1449      0.953      0.921      0.955      0.758
#                    주머니       1400       2622      0.972       0.97      0.988      0.743
#                    운동화       1400       2802      0.944      0.962      0.983      0.889
#                   남자구두       1400       2804      0.943      0.957      0.983      0.888
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47672 (\N{HANGUL SYLLABLE MEO}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50620 (\N{HANGUL SYLLABLE EOL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45576 (\N{HANGUL SYLLABLE NUN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51077 (\N{HANGUL SYLLABLE IB}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46973 (\N{HANGUL SYLLABLE RAG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46160 (\N{HANGUL SYLLABLE DU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46988 (\N{HANGUL SYLLABLE RAM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47672 (\N{HANGUL SYLLABLE MEO}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50620 (\N{HANGUL SYLLABLE EOL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44404 (\N{HANGUL SYLLABLE GUL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45576 (\N{HANGUL SYLLABLE NUN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51077 (\N{HANGUL SYLLABLE IB}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46973 (\N{HANGUL SYLLABLE RAG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# /home/msmlwork2/Python-3.9.0/kt2/lib/python3.9/site-packages/ultralytics/utils/metrics.py:304: UserWarning: Glyph 46160 (\N{HANGUL SYLLABLE DU}) missing from current font.
#   fig.savefig(plot_fname, dpi=250)
# Speed: 0.7ms preprocess, 5.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val

# %%
path = model.export(format="onnx")  # export the model to ONNX format
model_path = os.path.join(current_directory, "yolov8_man.pt")
torch.save(model.state_dict(), model_path)
print(f"Model has been saved to {model_path}")
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.9.0 torch-2.0.1+cu117 CPU (Intel Core(TM) i9-9980XE 3.00GHz)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 22, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 0.6s, saved as 'runs/detect/train/weights/best.onnx' (11.7 MB)
#
# Export complete (2.2s)
# Results saved to /home/msmlwork2/Documents/KT/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.onnx imgsz=640 data=/home/msmlwork2/Documents/KT/man.yaml
# Visualize:       https://netron.app
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Model has been saved to /home/msmlwork2/Documents/KT/yolov8_man.pt

# %%
# import shutil

# shutil.make_archive("/content/runs", 'zip', "/content/runs")
