# %%
import pandas as pd

df = pd.read_csv("C:/Users/user/Desktop/house.csv")
df.columns = ['exp', 'analysis']
df
# Out:
#                        exp                                           analysis
# 0                      집그림  피검자가 성장해온 가정상황을 나타내며 자신의 가정생활과 가족관계를 어떻게 인지하며 ...
# 1                    특수한 집  교회, 절 등 특수한 집을 그린 경우에는 반드시 '그린 후의 질문'을 해야 한다. ...
# 2                       지붕                          정신생활, 특히 생활의 공상 영역을 상징한다.
# 3                지붕이 허물어지고  자신의 통제력을 완전히 능가한 힘으로 인해 자신이 압 도되었다는 감정을 상징적으로 ...
# 4               금이 가 있는 그림                                                NaN
# ..                     ...                                                ...
# 84                창문이 없는 것     외계에 대한 관심의 결여와 적의 폐쇄적인 사고, 상당한 편집증적 경향성을 나타낸다.
# 85             길고 꼬불꼬불한 도로  대인관계에 있어서 처음에는 타인과의 접촉이 어려우나 점차 따뜻한 인간 관계를 맺는 ...
# 86   무너질 것 같은 집, 벼락이 떨어진 집  병적인 경우가 많다. 외부의 압력과 무의식의 욕구에 의해 자기가 지배되며, 그것을 ...
# 87  창문이 커튼이나 차양으로 막혀져 있는 것  타인과의 교섭을 싫어하고 강박 관념, 의심, 폐쇄적인 사고의 경향이 있음을 나타낸다...
# 88     엄중한 격자가 있는 창문이 많은 것                        심한 강박경향 때로는 항문적 가학관념을 나타낸다.
#
# [89 rows x 2 columns]

# %%
combined_string = '\n'.join(df['analysis'].astype(str))
ARTICLE_FORMAT = f'"""{combined_string}"""'
ARTICLE_FORMAT
# Out:
# '"""피검자가 성장해온 가정상황을 나타내며 자신의 가정생활과 가족관계를 어떻게 인지하며 그것에 대해 어떤 감정을 갖고 있는가를 보여주는 경우가 많다. 따라서 집 그림은 피검자가 현재의 가정을 어떻게 바라보고 있는가 하는 것 외에 이상적인 장래의 가정과 과거의 가정에 대한 소망을 나타낸다.\n교회, 절 등 특수한 집을 그린 경우에는 반드시 \'그린 후의 질문\'을 해야 한다. 자신의 가정에 대해 불만이나 갈등을 가지고 있는 경우가 많다.\n정신생활, 특히 생활의 공상 영역을 상징한다.\n자신의 통제력을 완전히 능가한 힘으로 인해 자신이 압 도되었다는 감정을 상징적으로 나타낸 것\nnan\n공상을 통제하는 힘이 약해져 있다는 것\nnan\n공상적인 경향이 자신의 통제를 벗어나는 것을 두려워하고 자기를 방어하고자 하는 사람에게서 자주 나타난다.\n자아의 완전함과 통제를 유지하고자 하는 의식적인 노력, 정신병의 초기에 자주 나타난다.\n강한 의식과 수반된 죄의식\n현실과의 접촉이 불충분한 것\n현실수준에서의 불안\n공상력이 없는 사람에게서 흔히 보여진다. 정신지체인 에게 많이 보여지며 보통의 지능을 가지고 있으면서 이러한 지붕을 그리는 사람은 위축된 성격을 갖고 있으며 구체적인 것만을 추구하는 경향을 보인다.\n언제나 공상에 열증하고 있는 것. 이것이 극단적이면 현저한 분열적 성격이나 정신분열증으로 의심할 필요가 있다.\n공상에 열중하며 외면적인 대인관계로부터 도피하려는 경향\n집착적인 사람들에게서 흔히 나타난다.\n자아의 붕괴를 감지하고 현 실과의 접촉이 적절하지 못 하다는 것을 나타낸다.\n성격의 붕괴가 임박하였다는 느낌과 자아의 통제가 약하다는 것을 의미함. 이것은 병적상태를 피하고자 노력하기 보다는 수동적으로 참고 나가자는 태도를 나타냄.\n붕괴하고 있는 자아를 가진 환자들의 그림에서 자주 보여진다\n벽의 선은 자아의 강도와 관계있다.\n성인의 경우에는 비판력과 현실검증이 부적당하고, 될 수 있는 한 장면을 구조화하려는 강박적인 욕구\n기질적인 질환으로 의심되며, 원시적인 충동이 통제되 지 않으며 이인중의 감정을 나타낸다.\n도피적인 사고, 우울경향, 대인관계에 시기심이 많고 반항적인 경향이 강한 것\n현재보다는 과거와 미래를 중요하게 생각하며 환경으로부터의 압력으로 인해 상처받기 쉬운 경우와 정서적 문제가 있거나 잠재적인 동성애로 간주되기 쉽다\n피검자의 대인관계에 대한 태도\n환경과의 접촉을 꺼리고 우유부단함에 지배되고 있음\n가정환경에서 타인과 접촉하지 않으려는 감정, 외계와의 교류를 원치 않는 냉정한 사람에게 많다.\n외부로부터 정서적인 따뜻함을 얻고 싶어하는 갈망과 노출\n경향\n특히 닫힌 덧문은 극단적인 철회를 나타낸다.\n가정에서 이중의 역할을 좋아하는 사람들에 의해서 그려진다. 배우자를 지키려는 사람들의 경우\n타인을 자신의 생활공간으로 들어오게 할 때 신중한 사람, 신뢰하기 전에 검사하는 사람\n자신의 생활 속으로 어떤 사람을 들어오도록 하는데 있어 커다란 어려움을 가진 여성들의 경우\n구순적 성격의 특징을 나타내는 경우가 많다.\n유아에게는 보통이지만 성인의 경우는 기질장애를 의심하게 하는 정신지체나 퇴행의 경향을 나타낸다.\n만족을 공상에서 구하며 현실과의 접촉이 적다\n도피적이며 외계에 대한 의심과 경계성을 나타냄. 자신의 공간이 침범당하는 것을 원치 않는 사람들의 그림에서 나타남\n남성 성기에의 관심\n의심이 많고 방어적임\n아주 의존적인 사람에게서 보이며 적극적인 사회접촉을 통해 타인에게 인상적인 존재가 되고 싶은 욕구를 나타낸다.\n도피적 경향\n신중하거나 의심이 많은 사람들에 의해 그려진다.\n회의감, 외부세계로부터 자기를 멀리하려는 것\n외계로부터의 위험에 대처하려는 강한 공포감과 적의를 가진 사람에게서 보여지며 편집증적인 경향의 사람에게도 보여진다.\n환경에 대해서 약간의 불안을 가지지만 일반적으로 자신을 통제하고 빈틈없이 행동하는 것\n여성생식기에 대한 고착이나 지나친 관심\n그 방에 사는 사람에 대한 지나친 관심을 갖는 경우가 있다.\n히스테리 환자의 경우에 보여진다.\n가정에서의 아름다움에 대한 관심, 수줍은 접근을 나타낸다\n자신의 집이 안전하기를 원하거나 자신의 집을 감옥처럼 생각하는 사람들에 의해 그려진다\n심리적인 거리감, 수줍음\n여성, 신사 혹은 부드러운 사람들에 의해 그려진다\n피검자의 마음속에 긴장이 존재하며 가정환경내에 갈등이나 정서 혼란이 있음\n가정의 따뜻함의 결여나 요도 에로티시즘의 정신-성적 발달단계\n그 방과 관련된 경험을 반영\n인색하고 성을 잘 내며 아는 체를 잘한다. 청결에의 강조, 숨는 장소\n아주 조용하고 우울해 보이는 경우: 우울중적 경향이 있는 사람을 위한 은신처. 성적 행위를 위한 장소, 병자를 위한 장소\n가정 혹은 자신에 대한 적개심\n자기가 느끼고 있는 안전을 방해받고 싶지 않다는 것\n명백한 시기심과 경계심, 가정으로부터 거부된 감정, 문제징후로 간주된다\n의존에 대한 강한 욕구, 양친에게 지배되고 있다는 감정\n어머니의 보호를 구하며 안전의 욕구를 지니고 있다.\n죄의식 혹은 "더립혀진 존재". 아름다움에 대한 정신적 탐색 등을 반영한다.\n철회와 상당한 편집증적 경향성\n개방과 환경적 접촉에 대한 갈망\n거세 불안. 자극을 주는 감정을 피하려는 것\nnan\n보다 친밀한 인간관계로서의 따뜻함과 남성성기의 상징\n항문적 가학성을 의미\n미래에 대한 염세적인 생각을 가지고 있는 것\n현실 검중력이 결핍된 병적 경향\n가정에서의 심리적 온정에 대한 지나친 관심, 남성에 대한 성적 관심, 힘에 대한 관심, 창조력에 대한 높은 관심, 노출 경향성\nnan\n양육을 위한 장소, 애정에 대한 강한 욕구\n사회화를 위한 장소\n높은 방어와 깊은 의심\n높은 방어와 깊은 의심, 요도에로티시즘, 남성성기에 대한 관심\n집둘레에 숲을 그리는 것은 방어 벽을 만들려는 것을 나타내며 산책길에 연결하여 그려진 숲은 어느정도 불안이 있으나 그것을 통 제하고자 하는 의식적인 시도\n사람을 나타낸다.\n균형이 잘 이루어진 경우는 어느 정도 통제력을 가지고 타인과 빈틈없는 접촉을 하고 있는 사람이 그리는 경우가 많다.\n타인으로부터 멀리하고 싶은 기본적 욕구를 표면적인 우정으로 은폐시키려는 시도\n사회적 상호관계의 환영을 말함 창도 없는 벽에 기대어 있는 계단은 접근과 관련된 갈등을 나타낸다.\n타인과의 교섭을 즐겨하지 않고 별개의 세계에 살고 싶다는 바람\n정신분열증의 징후\n외계에 대한 관심의 결여와 적의 폐쇄적인 사고, 상당한 편집증적 경향성을 나타낸다.\n대인관계에 있어서 처음에는 타인과의 접촉이 어려우나 점차 따뜻한 인간 관계를 맺는 사람의 그림에 많다. 그러나 너무 긴 도로는 타인과의 접촉을 피하려는 경향을 나타냄\n병적인 경우가 많다. 외부의 압력과 무의식의 욕구에 의해 자기가 지배되며, 그것을 자신의 힘으로 통제할 수 없다는 감정을 나타낸 경우가 많다. 또한 이런 그림은 성격의 붕괴를 막연하게 느끼고 있는 정신분열증 환자에게서도 볼 수 있다.\n타인과의 교섭을 싫어하고 강박 관념, 의심, 폐쇄적인 사고의 경향이 있음을 나타낸다. 한편으로는 가정의 아름다움에 대한 관심. 수줍은 접근을 나타낼 수도 있다.\n심한 강박경향 때로는 항문적 가학관념을 나타낸다."""'
